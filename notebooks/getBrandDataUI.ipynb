# %%
import tkinter as tk 
sys.path.append("/opt/miniconda3/lib/python3.7/site-packages") 
import pandas as pd
import os
import numpy as np
import csv

# %%
window = tk.Tk()
window.title('get brand information')
window.geometry('1200x700') 

# create element
lName = tk.Label(window, text='名称（例：星巴克）', bg='white', font=('Arial', 12), width=50, height=2)
eName = tk.Entry(window, show=None, font=('Arial', 14))
lNickname = tk.Label(window, text='其他称呼（例：Starbucks）', bg='white', font=('Arial', 12), width=50, height=2)
eNickname = tk.Entry(window, show=None, font=('Arial', 14))
lLogo = tk.Label(window, text='商标（放图片链接）', bg='white', font=('Arial', 12), width=50, height=2)
eLogo = tk.Entry(window, show=None, font=('Arial', 14))
lTrade = tk.Label(window, text='所属行业（例：食品 / 软饮）', bg='white', font=('Arial', 12), width=50, height=2)
eTrade = tk.Entry(window, show=None, font=('Arial', 14))
lCountry = tk.Label(window, text='国家（例：美国）', bg='white', font=('Arial', 12), width=50, height=2)
eCountry = tk.Entry(window, show=None, font=('Arial', 14))
lSlogan = tk.Label(window, text='口号（例：将每一粒咖啡豆的风味发挥尽致。）', bg='white', font=('Arial', 12), width=50, height=2)
eSlogan = tk.Entry(window, show=None, font=('Arial', 14))
lColor = tk.Label(window, text='颜色（例：00704a）', bg='white', font=('Arial', 12), width=50, height=2)
eColor = tk.Entry(window, show=None, font=('Arial', 14))
lMascot = tk.Label(window, text='吉祥物（例：Bearista）', bg='white', font=('Arial', 12), width=50, height=2)
eMascot = tk.Entry(window, show=None, font=('Arial', 14))
lMascotImg = tk.Label(window, text='吉祥物图片（放图片链接）', bg='white', font=('Arial', 12), width=50, height=2)
eMascotImg = tk.Entry(window, show=None, font=('Arial', 14))
lStandard = tk.Label(window, text='辅助图形/视觉规范（放图片链接）', bg='white', font=('Arial', 12), width=50, height=2)
eStandard = tk.Entry(window, show=None, font=('Arial', 14))
lProductFeature = tk.Label(window, text='产品特点（例：简洁 / 圆角 / 高科技）', bg='white', font=('Arial', 12), width=50, height=2)
eProductFeature = tk.Entry(window, show=None, font=('Arial', 14))
lProductName = tk.Label(window, text='产品名称（例：星冰乐）', bg='white', font=('Arial', 12), width=50, height=2)
eProductName = tk.Entry(window, show=None, font=('Arial', 14))
lProductImg = tk.Label(window, text='产品图片（放图片链接）', bg='white', font=('Arial', 12), width=50, height=2)
eProductImg = tk.Entry(window, show=None, font=('Arial', 14))
lSound = tk.Label(window, text='听觉（例：钢琴声）', bg='white', font=('Arial', 12), width=50, height=2)
eSound = tk.Entry(window, show=None, font=('Arial', 14))
lSmell = tk.Label(window, text='嗅觉（例：咖啡香）', bg='white', font=('Arial', 12), width=50, height=2)
eSmell = tk.Entry(window, show=None, font=('Arial', 14))
lTaste = tk.Label(window, text='味觉（例：黑咖啡）', bg='white', font=('Arial', 12), width=50, height=2)
eTaste = tk.Entry(window, show=None, font=('Arial', 14))
lTouch = tk.Label(window, text='触觉（例：金属感）', bg='white', font=('Arial', 12), width=50, height=2)
eTouch = tk.Entry(window, show=None, font=('Arial', 14))
lCognition = tk.Label(window, text='用户认知（例：杯子 / 星冰乐 / 猫爪杯 ）', bg='white', font=('Arial', 12), width=50, height=2)
eCognition = tk.Entry(window, show=None, font=('Arial', 14))
lRelevant = tk.Label(window, text='相关词条（例：麦当劳 / 瑞幸咖啡 / 雀巢 ）', bg='white', font=('Arial', 12), width=50, height=2)
eRelevant = tk.Entry(window, show=None, font=('Arial', 14))
lUserAge = tk.Label(window, text='用户年龄段（例：20-29）', bg='white', font=('Arial', 12), width=50, height=2)
eUserAge = tk.Entry(window, show=None, font=('Arial', 14))
lUserGender = tk.Label(window, text='用户性别（例：女）', bg='white', font=('Arial', 12), width=50, height=2)
eUserGender = tk.Entry(window, show=None, font=('Arial', 14))
lUserFeature = tk.Label(window, text='用户特征（例：白领）', bg='white', font=('Arial', 12), width=50, height=2)
eUserFeature = tk.Entry(window, show=None, font=('Arial', 14))
lPersonnality = tk.Label(window, text='品牌个性（例：激情 / 勇敢的 / 时髦的）', bg='white', font=('Arial', 12), width=50, height=2)
ePersonnality = tk.Entry(window, show=None, font=('Arial', 14))
lDesignFeature = tk.Label(window, text='品牌设计风格（例：时尚 / 洋气 / 文化）', bg='white', font=('Arial', 12), width=50, height=2)
eDesignFeature = tk.Entry(window, show=None, font=('Arial', 14))
lFeature = tk.Label(window, text='品牌特点（例：崇尚知识 / 尊重人本位）', bg='white', font=('Arial', 12), width=50, height=2)
eFeature = tk.Entry(window, show=None, font=('Arial', 14))
lStrength = tk.Label(window, text='品牌优势（例：专业咖啡烘焙 / 良好的服务体验）', bg='white', font=('Arial', 12), width=50, height=2)
eStrength = tk.Entry(window, show=None, font=('Arial', 14))
lCulture = tk.Label(window, text='品牌文化（例：咖啡文化）', bg='white', font=('Arial', 12), width=50, height=2)
eCulture = tk.Entry(window, show=None, font=('Arial', 14))
lStory = tk.Label(window, text='品牌故事', bg='white', font=('Arial', 12), width=50, height=2)
eStory = tk.Entry(window, show=None, font=('Arial', 14))
lURL = tk.Label(window, text='官网（例：https://www.starbucks.com/）', bg='white', font=('Arial', 12), width=50, height=2)
eURL = tk.Entry(window, show=None, font=('Arial', 14))

# the layout
lName.grid(row=1,column=1)
eName.grid(row=1,column=2)
lNickname.grid(row=2,column=1)
eNickname.grid(row=2,column=2)
lLogo.grid(row=3,column=1)
eLogo.grid(row=3,column=2)
lTrade.grid(row=4,column=1)
eTrade.grid(row=4,column=2)
lCountry.grid(row=5,column=1)
eCountry.grid(row=5,column=2)
lSlogan.grid(row=6,column=1)
eSlogan.grid(row=6,column=2)
lColor.grid(row=7,column=1)
eColor.grid(row=7,column=2)
lMascot.grid(row=8,column=1)
eMascot.grid(row=8,column=2)
lMascotImg.grid(row=9,column=1)
eMascotImg.grid(row=9,column=2)
lStandard.grid(row=10,column=1)
eStandard.grid(row=10,column=2)
lProductFeature.grid(row=11,column=1)
eProductFeature.grid(row=11,column=2)
lProductName.grid(row=12,column=1)
eProductName.grid(row=12,column=2)
lProductImg.grid(row=13,column=1)
eProductImg.grid(row=13,column=2)
lSound.grid(row=14,column=1)
eSound.grid(row=14,column=2)
lSmell.grid(row=15,column=1)
eSmell.grid(row=15,column=2)
lTaste.grid(row=1,column=3)
eTaste.grid(row=1,column=4)
lTouch.grid(row=2,column=3)
eTouch.grid(row=2,column=4)
lCognition.grid(row=3,column=3)
eCognition.grid(row=3,column=4)
lRelevant.grid(row=4,column=3)
eRelevant.grid(row=4,column=4)
lUserAge.grid(row=5,column=3)
eUserAge.grid(row=5,column=4)
lUserGender.grid(row=6,column=3)
eUserGender.grid(row=6,column=4)
lUserFeature.grid(row=7,column=3)
eUserFeature.grid(row=7,column=4)
lPersonnality.grid(row=8,column=3)
ePersonnality.grid(row=8,column=4)
lDesignFeature.grid(row=9,column=3)
eDesignFeature.grid(row=9,column=4)
lFeature.grid(row=10,column=3)
eFeature.grid(row=10,column=4)
lStrength.grid(row=11,column=3)
eStrength.grid(row=11,column=4)
lCulture.grid(row=12,column=3)
eCulture.grid(row=12,column=4)
lStory.grid(row=13,column=3)
eStory.grid(row=13,column=4)
lURL.grid(row=14,column=3)
eURL.grid(row=14,column=4)


buttonOK = tk.Button(window, text='OK', width=10,
               height=2, command=ok)
buttonOK.grid(row=30,column=1)

window.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/test/lib/python3.7/tkinter/__init__.py", line 1705, in __call__
#     return self.func(*args)
#   File "<ipython-input-24-96fac81be317>", line 45, in ok
#     createNodeByBrand(brandData.tail(1))
#   File "<ipython-input-23-60c3bf42ab64>", line 6, in createNodeByBrand
#     b = str(d.iloc[j]).split(' / ')
#   File "/opt/anaconda3/envs/test/lib/python3.7/site-packages/pandas/core/indexing.py", line 879, in __getitem__
#     return self._getitem_axis(maybe_callable, axis=axis)
#   File "/opt/anaconda3/envs/test/lib/python3.7/site-packages/pandas/core/indexing.py", line 1496, in _getitem_axis
#     self._validate_integer(key, axis)
#   File "/opt/anaconda3/envs/test/lib/python3.7/site-packages/pandas/core/indexing.py", line 1437, in _validate_integer
#     raise IndexError("single positional indexer is out-of-bounds")
# IndexError: single positional indexer is out-of-bounds

# %%
brandName = brandNickname = brandLogo = brandTrade = brandCountry = brandSlogan = brandColor = brandMascot = brandMascotImg = brandStandard = brandProductFeature = brandProductName = brandProductImg = brandSound = brandSmell = brandTaste = brandTouch = brandCognition = brandRelevant = brandUserAge = brandUserGender =  brandUserFeature = brandPersonnality = brandDesignFeature = brandFeature = brandStrength = brandCulture = brandStory = brandURL = ''

def ok():   # 在文本框内容最后接着插入输入内容
    brandName = eName.get()
    brandNickname = eNickname.get()
    brandLogo = eLogo.get()
    brandTrade = eTrade.get()
    brandCountry = eCountry.get()
    brandSlogan = eSlogan.get()
    brandColor = eColor.get()
    brandMascot = eMascot.get()
    brandMascotImg = eMascotImg.get()
    brandStandard = eStandard.get()
    brandProductFeature = eProductFeature.get()
    brandProductName = eProductName.get()
    brandProductImg = eProductImg.get()
    brandSound = eSound.get()
    brandSmell = eSmell.get()
    brandTaste = eTaste.get()
    brandTouch = eTouch.get()
    brandCognition = eCognition.get()
    brandRelevant = eRelevant.get()
    brandUserAge = eUserAge.get()
    brandUserGender = eUserGender.get()
    brandUserFeature = eUserFeature.get()
    brandPersonnality = ePersonnality.get()
    brandDesignFeature = eDesignFeature.get()
    brandFeature = eFeature.get()
    brandStrength = eStrength.get()
    brandCulture = eCulture.get()
    brandStory = eStory.get()
    brandURL = eURL.get()
    
    # add data to csv
    path  = "../data/brandInfo.csv"
    with open(path,'a+') as f:
        csv_write = csv.writer(f)
        data_row = [brandName,brandNickname,brandLogo,brandTrade,brandCountry,brandSlogan,brandColor,brandMascot,brandMascotImg,brandStandard,brandProductFeature,brandProductName,brandProductImg,brandSound,brandSmell,brandTaste,brandTouch,brandCognition,brandRelevant,brandUserAge,brandUserGender,brandUserFeature,brandPersonnality,brandDesignFeature,brandFeature,brandStrength,brandCulture,brandStory,brandURL]
        csv_write.writerow(data_row)
